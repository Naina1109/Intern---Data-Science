# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
news= pd.read_csv('train_fakenews.csv')
news
# Out:
#        Unnamed: 0     id                                           headline  \
# 0               0   9653  Ethics Questions Dogged Agriculture Nominee as...
# 1               1  10041  U.S. Must Dig Deep to Stop Argentina’s Lionel ...
# 2               2  19113  Cotton to House: ’Do Not Walk the Plank and Vo...
# 3               3   6868  Paul LePage, Besieged Maine Governor, Sends Co...
# 4               4   7596                       A Digital 9/11 If Trump Wins
# ...           ...    ...                                                ...
# 20795       20795   5671                                                NaN
# 20796       20796  14831        Albert Pike and the European Migrant Crisis
# 20797       20797  18142  Dakota Access Caught Infiltrating Protests to ...
# 20798       20798  12139  How to Stretch the Summer Solstice - The New Y...
# 20799       20799  15660  Emory University to Pay for ’100 Percent’ of U...
#
#                        written_by  \
# 0      Eric Lipton and Steve Eder
# 1                 David Waldstein
# 2                         Pam Key
# 3                    Jess Bidgood
# 4               Finian Cunningham
# ...                           ...
# 20795              NeverSurrender
# 20796               Rixon Stewart
# 20797                 Eddy Lavine
# 20798              Alison S. Cohn
# 20799                Tom Ciccotta
#
#                                                     news  label
# 0      WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0
# 1      HOUSTON  —   Venezuela had a plan. It was a ta...      0
# 2      Sunday on ABC’s “This Week,” while discussing ...      0
# 3      AUGUSTA, Me.  —   The beleaguered Republican g...      0
# 4        Finian Cunningham has written extensively on...      1
# ...                                                  ...    ...
# 20795  No, you'll be a dog licking of the vomit of yo...      1
# 20796  By Rixon Stewart on November 5, 2016 Rixon Ste...      1
# 20797  posted by Eddie You know the Dakota Access Pip...      1
# 20798  It’s officially summer, and the Society Boutiq...      0
# 20799  Emory University in Atlanta, Georgia, has anno...      0
#
# [20800 rows x 6 columns]

# %%
#check the total number of dataset
news.shape
# Out:
# (20800, 6)

# %%
# Check the infromation of dataset
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20800 non-null  int64
#  1   id          20800 non-null  int64
#  2   headline    20242 non-null  object
#  3   written_by  18843 non-null  object
#  4   news        20761 non-null  object
#  5   label       20800 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 975.1+ KB

# %%
# check the columns name
news.columns
# Out:
# Index(['Unnamed: 0', 'id', 'headline', 'written_by', 'news', 'label'], dtype='object')

# %%
# checking the nan values in the dataset
news.isnull().sum()
# Out:
# Unnamed: 0       0
# id               0
# headline       558
# written_by    1957
# news            39
# label            0
# dtype: int64

# %%
# visualize the nan values  via heatmap
sns.heatmap(news.isnull())
# Out:
# <AxesSubplot:>

# %%
# let's drop unneccessary coulmn from the dataset
news.drop(['Unnamed: 0','id'],axis=1, inplace=True)

# %%
# reset_index(): it will set the indices in order, starting from 0, and make it easier for us to work with the dataframe
news.reset_index(inplace= True)

# %%
# imputing 'Written_by' feature with unknown because sometimes there are anonymus authors
news['written_by'].fillna('unknown', inplace= True)

# %%
# filling up empty values in 'headline'  with 'No Headline'
news['headline'].fillna('no headlines', inplace= True)

# %%
# Dropping empty values in rows because we are detecting fake news here and for this news is needed
news.dropna(subset=['news'], inplace= True)

# %%
# Check the dataset again
news.head()
# Out:
#    index                                           headline  \
# 0      0  Ethics Questions Dogged Agriculture Nominee as...
# 1      1  U.S. Must Dig Deep to Stop Argentina’s Lionel ...
# 2      2  Cotton to House: ’Do Not Walk the Plank and Vo...
# 3      3  Paul LePage, Besieged Maine Governor, Sends Co...
# 4      4                       A Digital 9/11 If Trump Wins
#
#                    written_by  \
# 0  Eric Lipton and Steve Eder
# 1             David Waldstein
# 2                     Pam Key
# 3                Jess Bidgood
# 4           Finian Cunningham
#
#                                                 news  label
# 0  WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0
# 1  HOUSTON  —   Venezuela had a plan. It was a ta...      0
# 2  Sunday on ABC’s “This Week,” while discussing ...      0
# 3  AUGUSTA, Me.  —   The beleaguered Republican g...      0
# 4    Finian Cunningham has written extensively on...      1

# %%
# check the null values again
news.isnull().sum()
# Out:
# index         0
# headline      0
# written_by    0
# news          0
# label         0
# dtype: int64

# %%
sns.heatmap(news.isnull())
# Out:
# <AxesSubplot:>

# %%
# check the ration of fake news and non-fake news
print('Fake = ', round(len(news[news['label']==1])/len(news.label),2)*100, '%')
print('Not Fake = ', round(len(news[news['label']==0])/len(news.label),2)*100,'%')
# Out:
# Fake =  50.0 %
# Not Fake =  50.0 %

# %%
# Checking how many distinct writers are there
news['written_by'].value_counts()
# Out:
# unknown                               1918
# Pam Key                                243
# admin                                  193
# Jerome Hudson                          166
# Charlie Spiering                       141
#                                       ...
# Diane Cardwell and Clifford Krauss       1
# Jennifer Steinhauer and Steve Eder       1
# August Moliere                           1
# Dan Hyman                                1
# Anonymous Coward (UID 69826920)          1
# Name: written_by, Length: 4202, dtype: int64

# %%
#New columns for checking length of headline and news feature
news['length_headline'] = news.headline.str.len()
news['length_news'] = news.news.str.len()
news.head()
# Out:
#    index                                           headline  \
# 0      0  Ethics Questions Dogged Agriculture Nominee as...
# 1      1  U.S. Must Dig Deep to Stop Argentina’s Lionel ...
# 2      2  Cotton to House: ’Do Not Walk the Plank and Vo...
# 3      3  Paul LePage, Besieged Maine Governor, Sends Co...
# 4      4                       A Digital 9/11 If Trump Wins
#
#                    written_by  \
# 0  Eric Lipton and Steve Eder
# 1             David Waldstein
# 2                     Pam Key
# 3                Jess Bidgood
# 4           Finian Cunningham
#
#                                                 news  label  length_headline  \
# 0  WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0               84
# 1  HOUSTON  —   Venezuela had a plan. It was a ta...      0               72
# 2  Sunday on ABC’s “This Week,” while discussing ...      0              100
# 3  AUGUSTA, Me.  —   The beleaguered Republican g...      0              100
# 4    Finian Cunningham has written extensively on...      1               28
#
#    length_news
# 0         7936
# 1         6112
# 2          425
# 3         6516
# 4         9164

# %%
#converting all the text to lower form
news['headline'] = news.headline.str.lower()
news['written_by'] = news.written_by.str.lower()
news['news'] = news.news.str.lower()

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dines\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import string
import re
from gensim import corpora
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from sklearn.feature_extraction.text import TfidfVectorizer

from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk import pos_tag
from collections import Counter

# %%
# function to filter using POS tagging. This will be called inside the below function
def get_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Function for data cleaning.
def Processed_data(News):
    # Replace email addresses with 'email'
    News=re.sub(r'^.+@[^\.].*\.[a-z]{2,}$',' ', News)
        
    # Replace 10 digit phone numbers (formats include paranthesis, spaces, no spaces, dashes) with 'phonenumber'
    News=re.sub(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$',' ',News)
        
    # getting only words(i.e removing all the special characters)
    News = re.sub(r'[^\w]', ' ', News) 
        
    # getting only words(i.e removing all the" _ ")
    News = re.sub(r'[\_]', ' ', News) 
    
    # getting rid of unwanted characters(i.e remove all the single characters left)
    News=re.sub(r'\s+[a-zA-Z]\s+', ' ', News)
    
    # Removing extra whitespaces
    News=re.sub(r'\s+', ' ', News)

    #converting all the letters of the review into lowercase
    News = News.lower()
    
    # splitting every words from the sentences
    News = News.split()

    # iterating through each words and checking if they are stopwords or not,
    News=[word for word in News if not word in set(STOPWORDS)]
    
    # remove empty tokens
    News = [text for text in News if len(text) > 0]
    
    # getting pos tag text
    pos_tags = pos_tag(News)

    # considering words having length more than 3only
    News = [text for text in News if len(text) > 3]        
   
    # performing lemmatization operation and passing the word in get_pos function to get filtered using POS
    News = [(WordNetLemmatizer().lemmatize(text[0], get_pos(text[1])))for text in pos_tags]

   # considering words having length more than 3 only
    News = [text for text in News if len(text) > 3]
    News = ' '.join(News)
    return News

# %%
news['clean_headline']=news['headline'].apply(Processed_data)
news['clean_news']=news['news'].apply(Processed_data)
news.head()
# Out:
#    index                                           headline  \
# 0      0  ethics questions dogged agriculture nominee as...
# 1      1  u.s. must dig deep to stop argentina’s lionel ...
# 2      2  cotton to house: ’do not walk the plank and vo...
# 3      3  paul lepage, besieged maine governor, sends co...
# 4      4                       a digital 9/11 if trump wins
#
#                    written_by  \
# 0  eric lipton and steve eder
# 1             david waldstein
# 2                     pam key
# 3                jess bidgood
# 4           finian cunningham
#
#                                                 news  label  length_headline  \
# 0  washington  —   in sonny perdue’s telling, geo...      0               84
# 1  houston  —   venezuela had a plan. it was a ta...      0               72
# 2  sunday on abc’s “this week,” while discussing ...      0              100
# 3  augusta, me.  —   the beleaguered republican g...      0              100
# 4    finian cunningham has written extensively on...      1               28
#
#    length_news                                     clean_headline  \
# 0         7936  ethic question dogged agriculture nominee geor...
# 1         6112         deep stop argentina lionel messi york time
# 2          425      cotton house walk plank vote senate breitbart
# 3         6516  paul lepage besieged maine governor sends conf...
# 4         9164                                      digital trump
#
#                                           clean_news
# 0  washington sonny perdue telling georgian growi...
# 1  houston venezuela plan tactical approach desig...
# 2  sunday week discussing republican plan repeal ...
# 3  augusta beleaguered republican governor maine ...
# 4  finian cunningham written extensively internat...

# %%
#again making new column to check the length after preprocessing
news['clean_length_headline']=news.clean_headline.str.len()
news['clean_length_news']=news.clean_news.str.len()

news.head(10)
# Out:
#    index                                           headline  \
# 0      0  ethics questions dogged agriculture nominee as...
# 1      1  u.s. must dig deep to stop argentina’s lionel ...
# 2      2  cotton to house: ’do not walk the plank and vo...
# 3      3  paul lepage, besieged maine governor, sends co...
# 4      4                       a digital 9/11 if trump wins
# 5      5  whatever the outcome on november 8th the us wi...
# 6      6  rapid evolution saved this fish from pollution...
# 7      7  alabama prison officials retaliate against pri...
# 8      8                                       no headlines
# 9      9           can we live in a constant state of love?
#
#                    written_by  \
# 0  eric lipton and steve eder
# 1             david waldstein
# 2                     pam key
# 3                jess bidgood
# 4           finian cunningham
# 5                     unknown
# 6                joanna klein
# 7            brian sonenstein
# 8                 steventexas
# 9                     gillian
#
#                                                 news  label  length_headline  \
# 0  washington  —   in sonny perdue’s telling, geo...      0               84
# 1  houston  —   venezuela had a plan. it was a ta...      0               72
# 2  sunday on abc’s “this week,” while discussing ...      0              100
# 3  augusta, me.  —   the beleaguered republican g...      0              100
# 4    finian cunningham has written extensively on...      1               28
# 5  taming the corporate media beast whatever the ...      1              106
# 6  the state of new jersey says you can’t eat the...      0               79
# 7  advocates say prison officials at the kilby co...      1               88
# 8  people have made up their minds on president.\...      1               12
# 9  leave a reply \ntoni emerson – when we fall in...      1               40
#
#    length_news                                     clean_headline  \
# 0         7936  ethic question dogged agriculture nominee geor...
# 1         6112         deep stop argentina lionel messi york time
# 2          425      cotton house walk plank vote senate breitbart
# 3         6516  paul lepage besieged maine governor sends conf...
# 4         9164                                      digital trump
# 5        15285  outcome november collision course china federi...
# 6         4159  rapid evolution saved fish pollution study yor...
# 7         6311  alabama prison official retaliate prison strik...
# 8          782                                           headline
# 9         6386                           live constant state love
#
#                                           clean_news  clean_length_headline  \
# 0  washington sonny perdue telling georgian growi...                     68
# 1  houston venezuela plan tactical approach desig...                     42
# 2  sunday week discussing republican plan repeal ...                     45
# 3  augusta beleaguered republican governor maine ...                     80
# 4  finian cunningham written extensively internat...                     13
# 5  taming corporate medium beast outcome november...                     59
# 6  state jersey fish shellfish passaic river newa...                     52
# 7  advocate prison official kilby correctional fa...                     73
# 8  people mind president served elected district ...                      8
# 9  leave reply toni emerson fall love heart feel ...                     24
#
#    clean_length_news
# 0               4803
# 1               3632
# 2                212
# 3               3847
# 4               5888
# 5               9223
# 6               2473
# 7               3494
# 8                449
# 9               3760

# %%
# Total length removal from headline 
print ('Origian Length', news.length_headline.sum())
print ('Clean Length', news.clean_length_headline.sum())
print('Total Reduction = ',news['length_headline'].sum()-news['clean_length_headline'].sum())
# Out:
# Origian Length 1507286
# Clean Length 1040606
# Total Reduction =  466680

# %%
# Total length removed from news column
print ('Origian Length', news.length_news.sum())
print ('Clean Length', news.clean_length_news.sum())
print('Total Reduction = ',news['length_news'].sum()-news['clean_length_news'].sum())
# Out:
# Origian Length 94518924
# Clean Length 56207800
# Total Reduction =  38311124

# %%
# news distribution BEFORE cleaning
f,ax = plt.subplots(1,2,figsize = (15,8))

sns.distplot(news[news['label']==1]['length_news'],bins=20,ax=ax[0],label='Fake News distribution',color='r')

ax[0].set_xlabel('Fake News length')
ax[0].legend()

sns.distplot(news[news['label']==0]['length_news'],bins=20,ax=ax[1],label='True News distribution')
ax[1].set_xlabel('True News length')
ax[1].legend()

plt.show()

# %%
# news distribution AFTER cleaning
f,ax = plt.subplots(1,2,figsize = (15,8))

sns.distplot(news[news['label']==1]['clean_length_news'],bins=20,ax=ax[0],label='Fake News distribution',color='r')

ax[0].set_xlabel('Fake News length')
ax[0].legend()

sns.distplot(news[news['label']==0]['clean_length_news'],bins=20,ax=ax[1],label='True News distribution')
ax[1].set_xlabel('True News length')
ax[1].legend()

plt.show()

# %%
#Getting sense of loud words in Fake News - Articles
from wordcloud import WordCloud

fake = news['clean_news'][news['label']==1]

fake_cloud = WordCloud(width=700,height=500,background_color='white',max_words=200).generate(' '.join(fake))

plt.figure(figsize=(10,8),facecolor='r')
plt.imshow(fake_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#Getting sense of loud words in Not Fake News - Articles

not_fake = news['clean_news'][news['label']==0]

not_fake_cloud = WordCloud(width=700,height=500,background_color='white',max_words=200).generate(' '.join(not_fake))

plt.figure(figsize=(10,8),facecolor='r')
plt.imshow(not_fake_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#Getting sense of loud words in Fake News - Headline

fake = news['clean_headline'][news['label']==1]

fake_cloud = WordCloud(width=700,height=500,background_color='white',max_words=200).generate(' '.join(fake))

plt.figure(figsize=(10,8),facecolor='r')
plt.imshow(fake_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#Getting sense of loud words in Not Fake News - Headline

not_fake = news['clean_headline'][news['label']==0]

not_fake_cloud = WordCloud(width=700,height=500,background_color='white',max_words=200).generate(' '.join(not_fake))

plt.figure(figsize=(10,8),facecolor='r')
plt.imshow(not_fake_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # PRE PREOCESSING

# %%
from collections import Counter
#for counting frequently occurence of words occuring=f in fake and real news headline.
count1 = Counter(" ".join(news[news['label']==1]["headline"]).split()).most_common(50)
count2 = Counter(" ".join(news[news['label']==0]["headline"]).split()).most_common(50)
dataframe=pd.DataFrame()
print("TOP 50 Words in Each Category (Word,Counts)")
dataframe['Most Frequent Words in Fake News']=count1
dataframe['Most Frequent Words in real/authentic news']=count2
dataframe
# Out:
# TOP 50 Words in Each Category (Word,Counts)
#    Most Frequent Words in Fake News Most Frequent Words in real/authentic news
# 0                       (the, 3422)                                  (-, 8665)
# 1                        (to, 2599)                                (the, 8191)
# 2                        (of, 1925)                                (new, 6681)
# 3                        (in, 1627)                               (york, 6328)
# 4                         (a, 1207)                              (times, 6275)
# 5                       (and, 1203)                                 (to, 2859)
# 6                        (on, 1180)                          (breitbart, 2394)
# 7                       (for, 1177)                                 (in, 2172)
# 8                     (trump, 1068)                                 (of, 1887)
# 9                         (is, 990)                                  (a, 1686)
# 10                   (hillary, 837)                              (trump, 1465)
# 11                   (clinton, 746)                                (for, 1261)
# 12                        (no, 716)                                (and, 1187)
# 13                        (by, 666)                                 (on, 1141)
# 14                 (headlines, 563)                                  (is, 798)
# 15                      (with, 546)                                  (at, 679)
# 16                         (–, 534)                                (with, 666)
# 17                         (-, 512)                              (donald, 620)
# 18                      (from, 422)                                  (as, 479)
# 19                       (new, 421)                                (from, 431)
# 20                       (are, 412)                             (trump’s, 404)
# 21                  (election, 384)                               (after, 388)
# 22                        (at, 374)                                  (by, 384)
# 23                      (will, 364)                                (u.s., 362)
# 24                        (us, 362)                                (your, 336)
# 25                        (as, 359)                                (over, 299)
# 26                         (|, 336)                                 (not, 268)
# 27                   (comment, 326)                                (says, 259)
# 28                      (this, 323)                                 (how, 254)
# 29                     (about, 318)                                  (be, 248)
# 30                      (what, 318)                                 (are, 246)
# 31                      (that, 311)                                (will, 237)
# 32                        (be, 306)                                 (his, 225)
# 33                       (fbi, 298)                                  (it, 214)
# 34                      (news, 298)                            (briefing, 209)
# 35                       (you, 289)                               (obama, 208)
# 36                       (war, 285)                                  (an, 206)
# 37                     (after, 276)                             (hillary, 204)
# 38                         (&, 265)                               (house, 196)
# 39                       (how, 263)                               (state, 193)
# 40                    (russia, 258)                                (that, 191)
# 41                        (it, 257)                              (trump,, 182)
# 42                       (not, 256)                                 (who, 179)
# 43                    (donald, 252)                             (clinton, 175)
# 44                     (world, 241)                                (have, 174)
# 45                       (why, 237)                                 (but, 170)
# 46                      (just, 233)                           (president, 170)
# 47                      (over, 212)                                (what, 168)
# 48                       (has, 206)                               (about, 166)
# 49                       (now, 203)                                 (you, 163)

# %%
#for counting frequently occurence of word in fake and real news.
count1 = Counter(" ".join(news[news['label']==1]["news"]).split()).most_common(50)
count2 = Counter(" ".join(news[news['label']==0]["news"]).split()).most_common(50)
dataframe=pd.DataFrame()
print("TOP 50 Words in Each Category (Word,Counts)")
dataframe['Most Frequent Words in fake news']=count1
dataframe['Most Frequent Words in real/authentic news']=count2
dataframe
# Out:
# TOP 50 Words in Each Category (Word,Counts)
#    Most Frequent Words in fake news Most Frequent Words in real/authentic news
# 0                     (the, 376063)                              (the, 526903)
# 1                      (of, 178904)                               (to, 244219)
# 2                      (to, 178675)                               (of, 237775)
# 3                     (and, 163122)                                (a, 228497)
# 4                       (a, 128300)                              (and, 212877)
# 5                      (in, 118458)                               (in, 186986)
# 6                     (that, 83915)                             (that, 118658)
# 7                       (is, 79678)                               (for, 85047)
# 8                      (for, 57285)                                (on, 80909)
# 9                       (on, 46640)                                (is, 72842)
# 10                      (as, 42248)                                (he, 70985)
# 11                    (with, 40506)                               (was, 67285)
# 12                      (it, 39177)                               (mr., 64170)
# 13                     (are, 38172)                              (with, 60473)
# 14                    (this, 35677)                                (as, 55239)
# 15                      (by, 35475)                               (his, 50355)
# 16                      (be, 33960)                                (it, 48242)
# 17                     (was, 32892)                                (at, 47882)
# 18                    (have, 31457)                                 (”, 45601)
# 19                     (not, 28312)                                (by, 42251)
# 20                    (from, 27447)                              (from, 40223)
# 21                    (they, 26398)                              (have, 39960)
# 22                     (has, 26064)                              (said, 39384)
# 23                     (you, 25961)                                 (—, 39182)
# 24                      (at, 24393)                                (an, 38185)
# 25                       (i, 24223)                               (not, 37966)
# 26                      (he, 23973)                               (has, 37506)
# 27                      (we, 23133)                               (but, 37089)
# 28                      (an, 21938)                                (be, 35998)
# 29                     (but, 21623)                               (who, 35713)
# 30                    (will, 21556)                               (are, 33725)
# 31                   (their, 20377)                               (had, 33703)
# 32                      (or, 20174)                              (they, 31159)
# 33                     (his, 18741)                                 (i, 27194)
# 34                     (who, 18444)                              (this, 26369)
# 35                     (all, 16485)                               (she, 26188)
# 36                   (about, 15688)                             (about, 25215)
# 37                      (if, 15615)                             (their, 24661)
# 38                    (been, 15028)                                (or, 23569)
# 39                    (what, 14860)                              (were, 23450)
# 40                   (would, 14325)                               (her, 22883)
# 41                    (more, 14077)                             (trump, 22620)
# 42                     (one, 13980)                             (would, 22497)
# 43                   (trump, 13641)                              (been, 21587)
# 44                   (which, 13539)                              (more, 21214)
# 45                     (can, 13412)                               (one, 20428)
# 46                 (clinton, 13303)                               (you, 20136)
# 47                    (were, 13143)                               (new, 19212)
# 48                  (people, 13099)                             (which, 19194)
# 49                     (our, 12950)                              (will, 19051)

# %% [markdown]
# # POST PROCESSING

# %%
#for counting frequently occurence of words occuring in fake and real news headline.
count1 = Counter(" ".join(news[news['label']==1]["clean_headline"]).split()).most_common(50)
count2 = Counter(" ".join(news[news['label']==0]["clean_headline"]).split()).most_common(50)
dataframe=pd.DataFrame()
print("TOP 50 Words in Each Category (Word,Counts)")
dataframe['Most Frequent Words in Fake News']=count1
dataframe['Most Frequent Words in real/authentic news']=count2
dataframe
# Out:
# TOP 50 Words in Each Category (Word,Counts)
#    Most Frequent Words in Fake News Most Frequent Words in real/authentic news
# 0                     (trump, 1454)                               (time, 6378)
# 1                   (hillary, 1048)                               (york, 6345)
# 2                    (clinton, 975)                          (breitbart, 2399)
# 3                   (headline, 565)                              (trump, 2274)
# 4                   (election, 542)                              (donald, 627)
# 5                      (video, 388)                               (obama, 296)
# 6                     (russia, 346)                             (clinton, 293)
# 7                       (news, 346)                               (state, 260)
# 8                    (comment, 334)                            (briefing, 233)
# 9                    (america, 311)                               (house, 229)
# 10                     (email, 305)                           (president, 227)
# 11                     (world, 286)                             (hillary, 215)
# 12                     (obama, 284)                              (attack, 215)
# 13                    (donald, 260)                                (news, 206)
# 14                  (american, 231)                                (year, 199)
# 15                      (2016, 213)                              (report, 196)
# 16                     (state, 200)                               (white, 190)
# 17                 (wikileaks, 184)                               (woman, 186)
# 18                      (vote, 181)                              (russia, 184)
# 19                  (breaking, 180)                              (police, 171)
# 20                  (campaign, 176)                            (american, 162)
# 21                      (year, 172)                              (medium, 154)
# 22                      (time, 171)                             (evening, 149)
# 23                 (president, 171)                                (anti, 142)
# 24                   (russian, 168)                                (plan, 139)
# 25                     (black, 162)                            (election, 138)
# 26                    (medium, 159)                              (border, 135)
# 27                     (putin, 155)                            (democrat, 133)
# 28                    (people, 142)                               (china, 133)
# 29                     (voter, 141)                               (court, 129)
# 30                     (syria, 140)                               (syria, 126)
# 31                      (life, 139)                          (republican, 122)
# 32                    (police, 137)                              (health, 120)
# 33                    (report, 134)                                (case, 116)
# 34                     (woman, 131)                              (leader, 114)
# 35                     (right, 131)                                (fake, 114)
# 36                     (white, 126)                             (america, 113)
# 37             (investigation, 123)                               (right, 112)
# 38                    (muslim, 117)                           (obamacare, 111)
# 39                    (voting, 113)                                (city, 109)
# 40                     (watch, 112)                          (california, 109)
# 41                   (million, 108)                               (north, 107)
# 42                     (child, 108)                                (life, 107)
# 43                    (attack, 107)                             (million, 106)
# 44                 (supporter, 107)                            (campaign, 105)
# 45                      (like, 106)                                (call, 105)
# 46                (government, 103)                               (world, 102)
# 47                    (source, 102)                               (watch, 100)
# 48                       (anti, 95)                             (russian, 100)
# 49                       (want, 93)                                 (deal, 97)

# %%
#for counting frequently occurence of word in fake and real news.
count1 = Counter(" ".join(news[news['label']==1]["clean_news"]).split()).most_common(50)
count2 = Counter(" ".join(news[news['label']==0]["clean_news"]).split()).most_common(50)
dataframe=pd.DataFrame()
print("TOP 50 Words in Each Category (Word,Counts)")
dataframe['Most Frequent Words in fake news']=count1
dataframe['Most Frequent Words in real/authentic news']=count2
dataframe
# Out:
# TOP 50 Words in Each Category (Word,Counts)
#    Most Frequent Words in fake news Most Frequent Words in real/authentic news
# 0                    (trump, 20237)                              (said, 68179)
# 1                  (clinton, 20193)                             (trump, 36170)
# 2                   (people, 16923)                             (state, 22507)
# 3                    (state, 15435)                              (year, 21586)
# 4                  (hillary, 12769)                            (people, 20027)
# 5                     (time, 12641)                              (time, 18079)
# 6                     (said, 11874)                         (president, 17288)
# 7                     (year, 11806)                              (like, 16333)
# 8                 (american, 10569)                          (american, 12031)
# 9                     (like, 10562)                            (united, 10194)
# 10                 (election, 9696)                            (country, 9997)
# 11                    (world, 9254)                               (news, 9422)
# 12               (government, 8916)                         (government, 9192)
# 13                (president, 8783)                              (house, 8828)
# 14                     (2016, 8544)                           (official, 8825)
# 15                  (country, 7673)                         (republican, 8638)
# 16                    (right, 7664)                            (company, 8630)
# 17                    (obama, 7549)                            (clinton, 8293)
# 18                    (email, 6859)                              (woman, 7933)
# 19                   (medium, 6824)                              (group, 7894)
# 20                     (know, 6778)                               (city, 7834)
# 21                   (russia, 6746)                               (week, 7736)
# 22                 (campaign, 6253)                              (obama, 7552)
# 23                     (news, 5525)                              (right, 7441)
# 24                     (life, 5441)                              (white, 7421)
# 25                  (america, 5366)                           (campaign, 7406)
# 26                   (donald, 5321)                               (work, 7304)
# 27                    (thing, 5300)                              (going, 7221)
# 28                    (think, 5293)                              (think, 7099)
# 29                     (need, 5259)                               (want, 7032)
# 30                     (want, 5244)                               (told, 6834)
# 31                    (going, 5205)                            (percent, 6833)
# 32                (political, 5105)                              (world, 6826)
# 33                    (white, 5016)                            (million, 6721)
# 34                  (russian, 4953)                           (national, 6622)
# 35                    (power, 4930)                               (know, 6603)
# 36                     (vote, 4888)                               (york, 6558)
# 37                   (united, 4871)                             (police, 6472)
# 38                     (good, 4857)                              (party, 6443)
# 39                     (come, 4739)                              (month, 6387)
# 40                    (party, 4581)                             (family, 6322)
# 41                    (woman, 4537)                               (life, 6290)
# 42                    (force, 4503)                               (case, 6227)
# 43                     (work, 4478)                          (including, 6162)
# 44                    (group, 4362)                          (according, 5989)
# 45                   (report, 4350)                          (political, 5953)
# 46                 (military, 4343)                               (good, 5905)
# 47                   (public, 4328)                             (public, 5851)
# 48                  (million, 4317)                             (member, 5807)
# 49                   (policy, 4288)                            (twitter, 5795)

# %% [markdown]
# # FEATURE EXTRACTION

# %% [markdown]
# # 1. Convert text into vectors using TF-IDF

# %%
# Split feature and label

# creating the TF-IDF vectorizer fn in order to convert the tokens from the train documents into vectors so that machine can do further processing
def Tf_idf(text):
    tfid = TfidfVectorizer(min_df=2)
    return tfid.fit_transform(text)

# %%
# Inserting vectorized values in a variable x, which will be used in training the model 
x=Tf_idf(news['written_by'] + news['clean_headline'] + news['clean_news'])

# checking the shape of the data which is inserted in x which will be used for model training.
print("Shape of x: ",x.shape)
# Out:
# Shape of x:  (20761, 79312)

# %%
y = news['label']

# %%
y.shape
# Out:
# (20761,)

# %%
# Importing useful libraries for model training

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier

# Ensemble Techniques...

from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier

# Model selection libraries...
from sklearn.model_selection import cross_val_score, cross_val_predict, train_test_split
from sklearn.model_selection import GridSearchCV

# Importing some metrics we can use to evaluate our model performance.... 
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix,log_loss
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.metrics import precision_score, recall_score, f1_score


# Creating instances for different Classifiers

RF=RandomForestClassifier()
LR=LogisticRegression()
MNB=MultinomialNB()
DT=DecisionTreeClassifier()
AD=AdaBoostClassifier()
XG=XGBClassifier(eval_metric='mlogloss')

# %%
# List of Models
models=[]
models.append(('LogisticRegression',LR))
models.append(('MultinomialNB()',MNB))
models.append(('DecisionTreeClassifier',DT))
models.append(('RandomForestClassifier',RF))
models.append(('AdaBoostClassifier',AD))
models.append(('XGBClassifier',XG))

# %%
# Finding best Random State and then calculate Maximum Accuracy Score
def max_acc_score(clf,x,y):
    max_acc_score=0
    final_r_state=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=r_state,stratify=y)
        clf.fit(x_train,y_train)
        y_pred=clf.predict(x_test)
        acc_score=accuracy_score(y_test,y_pred)
        if acc_score > max_acc_score:
            max_acc_score=acc_score
            final_r_state=r_state
    print('Max Accuracy Score corresponding to Random State ', final_r_state, 'is:', max_acc_score)
    print('\n')
    return final_r_state

# %%
Model=[]
Score=[]
Acc_score=[]
cvs=[]
rocscore=[]
logloss=[]
#For Loop to Calculate Accuracy Score, Cross Val Score, Classification Report, Confusion Matrix,logloss

for name,model in models:
    print('**',name,'**')
    print('\n')
    Model.append(name)
    print(model)
    print('\n')
    
#calling a function which will calculate the max accuracy score for each model and return best random state.
    r_state=max_acc_score(model,x,y)
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=r_state,stratify=y)
    model.fit(x_train,y_train)
    
#Accuracy Score
    y_pred=model.predict(x_test)
    acc_score=accuracy_score(y_test,y_pred)
    print('Accuracy Score : ',acc_score)
    Acc_score.append(acc_score*100)
    
#Finding Cross_val_score 
    cv_score=cross_val_score(model,x,y,cv=10,scoring='roc_auc').mean()
    print('Cross Val Score : ', cv_score)
    cvs.append(cv_score*100)
    
#Roc auc score  
    false_positive_rate,true_positive_rate, thresholds=roc_curve(y_test,y_pred)
    roc_auc=auc(false_positive_rate, true_positive_rate)
    print('roc auc score : ', roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    
#logloss
    loss = log_loss(y_test,y_pred)
    print('Log loss : ', loss)
    logloss.append(loss)
    
#Classification Report     
    print('Classification Report:\n',classification_report(y_test,y_pred))
    print('\n')
    
    print('Confusion Matrix:\n',confusion_matrix(y_test,y_pred))
    print('\n')
    

    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC = %0.2f'% roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True_positive_rate')
    plt.xlabel('False_positive_rate')
    print('\n\n')
# Out:
# ** LogisticRegression **
#
#
# LogisticRegression()
#
#
# Max Accuracy Score corresponding to Random State  43 is: 0.9460587574249478
#
#
# Accuracy Score :  0.9460587574249478
# Cross Val Score :  0.987008107086735
# roc auc score :  0.9460581263631292
#
#
# Log loss :  1.86308556793523
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95      3116
#            1       0.95      0.94      0.95      3113
#
#     accuracy                           0.95      6229
#    macro avg       0.95      0.95      0.95      6229
# weighted avg       0.95      0.95      0.95      6229
#
#
#
# Confusion Matrix:
#  [[2952  164]
#  [ 172 2941]]
#
#
#
#
#
# ** MultinomialNB() **
#
#
# MultinomialNB()
#
#
# Max Accuracy Score corresponding to Random State  69 is: 0.8781505859688553
#
#
# Accuracy Score :  0.8781505859688553
# Cross Val Score :  0.9741080535277691
# roc auc score :  0.8780997593016491
#
#
# Log loss :  4.208536211784581
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89      3116
#            1       0.98      0.77      0.86      3113
#
#     accuracy                           0.88      6229
#    macro avg       0.90      0.88      0.88      6229
# weighted avg       0.90      0.88      0.88      6229
#
#
#
# Confusion Matrix:
#  [[3065   51]
#  [ 708 2405]]
#
#
#
#
#
# ** DecisionTreeClassifier **
#
#
# DecisionTreeClassifier()
#
#
# Max Accuracy Score corresponding to Random State  89 is: 0.9314496708942045
#
#
# Accuracy Score :  0.9288810402953925
# Cross Val Score :  0.9274617079958472
# roc auc score :  0.9288815650299976
#
#
# Log loss :  2.4563907292289664
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      3116
#            1       0.93      0.93      0.93      3113
#
#     accuracy                           0.93      6229
#    macro avg       0.93      0.93      0.93      6229
# weighted avg       0.93      0.93      0.93      6229
#
#
#
# Confusion Matrix:
#  [[2891  225]
#  [ 218 2895]]
#
#
#
#
#
# ** RandomForestClassifier **
#
#
# RandomForestClassifier()
#
#
# Max Accuracy Score corresponding to Random State  68 is: 0.9381923262160861
#
#
# Accuracy Score :  0.9338577620805908
# Cross Val Score :  0.9861717345421338
# roc auc score :  0.9338456850171151
#
#
# Log loss :  2.2844883967208656
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94      3116
#            1       0.96      0.91      0.93      3113
#
#     accuracy                           0.93      6229
#    macro avg       0.93      0.93      0.93      6229
# weighted avg       0.93      0.93      0.93      6229
#
#
#
# Confusion Matrix:
#  [[2988  128]
#  [ 284 2829]]
#
#
#
#
#
# ** AdaBoostClassifier **
#
#
# AdaBoostClassifier()
#
#
# Max Accuracy Score corresponding to Random State  82 is: 0.9457376786000963
#
#
# Accuracy Score :  0.9457376786000963
# Cross Val Score :  0.9819793019532235
# roc auc score :  0.9457385938383367
#
#
# Log loss :  1.874176649707834
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      3116
#            1       0.94      0.95      0.95      3113
#
#     accuracy                           0.95      6229
#    macro avg       0.95      0.95      0.95      6229
# weighted avg       0.95      0.95      0.95      6229
#
#
#
# Confusion Matrix:
#  [[2941  175]
#  [ 163 2950]]
#
#
#
#
#
# ** XGBClassifier **
#
#
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               eval_metric='mlogloss', gamma=None, gpu_id=None,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None)
#
#
# Max Accuracy Score corresponding to Random State  53 is: 0.9722266816503452
#
#
# Accuracy Score :  0.9722266816503452
# Cross Val Score :  0.9948777710098924
# roc auc score :  0.9722267525268791
#
#
# Log loss :  0.9592676001438402
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3116
#            1       0.97      0.97      0.97      3113
#
#     accuracy                           0.97      6229
#    macro avg       0.97      0.97      0.97      6229
# weighted avg       0.97      0.97      0.97      6229
#
#
#
# Confusion Matrix:
#  [[3029   87]
#  [  86 3027]]

# %%
scores=pd.DataFrame({'Model': Model,'Accuracy Score': Acc_score,'Cross Val Score':cvs,'Log_Loss':logloss,
                     'Roc_Auc_curve':rocscore}) 
scores.style.background_gradient(cmap='Spectral')
# Out:
# <style  type="text/css" >
# #T_d46c4038_efa0_11eb_afc0_005056c00008row0_col1,#T_d46c4038_efa0_11eb_afc0_005056c00008row0_col4{
#             background-color:  #9cd7a4;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row0_col2{
#             background-color:  #3990ba;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row0_col3{
#             background-color:  #fba05b;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row1_col1,#T_d46c4038_efa0_11eb_afc0_005056c00008row1_col4,#T_d46c4038_efa0_11eb_afc0_005056c00008row2_col2,#T_d46c4038_efa0_11eb_afc0_005056c00008row5_col3{
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row1_col2{
#             background-color:  #aedea3;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row1_col3,#T_d46c4038_efa0_11eb_afc0_005056c00008row5_col1,#T_d46c4038_efa0_11eb_afc0_005056c00008row5_col2,#T_d46c4038_efa0_11eb_afc0_005056c00008row5_col4{
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row2_col1,#T_d46c4038_efa0_11eb_afc0_005056c00008row2_col4{
#             background-color:  #f5fbaf;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row2_col3{
#             background-color:  #fff2aa;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row3_col1,#T_d46c4038_efa0_11eb_afc0_005056c00008row3_col4{
#             background-color:  #e8f69b;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row3_col2{
#             background-color:  #4199b6;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row3_col3{
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row4_col1,#T_d46c4038_efa0_11eb_afc0_005056c00008row4_col4{
#             background-color:  #9fd8a4;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row4_col2{
#             background-color:  #60bba8;
#             color:  #000000;
#         }#T_d46c4038_efa0_11eb_afc0_005056c00008row4_col3{
#             background-color:  #fba35c;
#             color:  #000000;
#         }</style><table id="T_d46c4038_efa0_11eb_afc0_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy Score</th>        <th class="col_heading level0 col2" >Cross Val Score</th>        <th class="col_heading level0 col3" >Log_Loss</th>        <th class="col_heading level0 col4" >Roc_Auc_curve</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d46c4038_efa0_11eb_afc0_005056c00008level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row0_col0" class="data row0 col0" >LogisticRegression</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row0_col1" class="data row0 col1" >94.605876</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row0_col2" class="data row0 col2" >98.700811</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row0_col3" class="data row0 col3" >1.863086</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row0_col4" class="data row0 col4" >94.605813</td>
#             </tr>
#             <tr>
#                         <th id="T_d46c4038_efa0_11eb_afc0_005056c00008level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row1_col0" class="data row1 col0" >MultinomialNB()</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row1_col1" class="data row1 col1" >87.815059</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row1_col2" class="data row1 col2" >97.410805</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row1_col3" class="data row1 col3" >4.208536</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row1_col4" class="data row1 col4" >87.809976</td>
#             </tr>
#             <tr>
#                         <th id="T_d46c4038_efa0_11eb_afc0_005056c00008level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row2_col0" class="data row2 col0" >DecisionTreeClassifier</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row2_col1" class="data row2 col1" >92.888104</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row2_col2" class="data row2 col2" >92.746171</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row2_col3" class="data row2 col3" >2.456391</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row2_col4" class="data row2 col4" >92.888157</td>
#             </tr>
#             <tr>
#                         <th id="T_d46c4038_efa0_11eb_afc0_005056c00008level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row3_col0" class="data row3 col0" >RandomForestClassifier</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row3_col1" class="data row3 col1" >93.385776</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row3_col2" class="data row3 col2" >98.617173</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row3_col3" class="data row3 col3" >2.284488</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row3_col4" class="data row3 col4" >93.384569</td>
#             </tr>
#             <tr>
#                         <th id="T_d46c4038_efa0_11eb_afc0_005056c00008level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row4_col0" class="data row4 col0" >AdaBoostClassifier</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row4_col1" class="data row4 col1" >94.573768</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row4_col2" class="data row4 col2" >98.197930</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row4_col3" class="data row4 col3" >1.874177</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row4_col4" class="data row4 col4" >94.573859</td>
#             </tr>
#             <tr>
#                         <th id="T_d46c4038_efa0_11eb_afc0_005056c00008level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row5_col0" class="data row5 col0" >XGBClassifier</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row5_col1" class="data row5 col1" >97.222668</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row5_col2" class="data row5 col2" >99.487777</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row5_col3" class="data row5 col3" >0.959268</td>
#                         <td id="T_d46c4038_efa0_11eb_afc0_005056c00008row5_col4" class="data row5 col4" >97.222675</td>
#             </tr>
#     </tbody></table>

# %%
plt.xticks(rotation=90)
sns.barplot(x=Model,y=Acc_score)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # FINAL MODEL

# %% [raw]
# We choose XGBoost Classifier model as the final one,as it gives hightest accuracy score & also log_loss value is minimum which indicates better prediction

# %%
# Using XGBClassifier for final model...
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=83,test_size=.30)
XG=XGBClassifier(eval_metric='mlogloss')
XG.fit(x_train,y_train)
XG.score(x_train,y_train)
XGpred=XG.predict(x_test)
print('Accuracy Score:','\n',accuracy_score(y_test,XGpred))
print('Log_Loss:','\n',log_loss(y_test,XGpred))
print('Confusion Matrix:','\n',confusion_matrix(y_test,XGpred))
print('Classification Report:','\n',classification_report(y_test,XGpred))
# Out:
# Accuracy Score:
#  0.9622732380799486
# Log_Loss:
#  1.3030531384917003
# Confusion Matrix:
#  [[2987  132]
#  [ 103 3007]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      3119
#            1       0.96      0.97      0.96      3110
#
#     accuracy                           0.96      6229
#    macro avg       0.96      0.96      0.96      6229
# weighted avg       0.96      0.96      0.96      6229

# %%
# Make predictions with probabilities
y_probs = XG.predict_proba(x_test)

# Keep the probabilites of the positive class only
y_probs = y_probs[:, 1]

# Calculate fpr, tpr and thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_probs)

# Check the false positive rate
fpr
plt.plot([0,1],[0,1])
plt.plot(fpr,tpr,label='XGB Classifier')
plt.xlabel('false positive rate')
plt.ylabel('True positive rate')
plt.title('XGB Classifier')
plt.show()
print('roc_auc_score = ',roc_auc_score(y_test, y_probs))
# Out:
# roc_auc_score =  0.9939710868662043

# %%
# Printing predicted values
pred_value=pd.DataFrame(data=y_test,)
pred_value['Predicted values']=XGpred
pred_value
# Out:
#        label  Predicted values
# 15583      1                 1
# 11115      0                 0
# 7115       1                 1
# 9514       0                 0
# 7059       0                 0
# ...      ...               ...
# 8378       0                 0
# 181        1                 1
# 2110       1                 1
# 14803      1                 1
# 15751      1                 1
#
# [6229 rows x 2 columns]

# %%
# Saving the best model.
import joblib
joblib.dump(XG,'Fake_news_Predict.pkl')
# Out:
# ['Fake_news_Predict.pkl']

# %%
# Saving the Predicted values in csv file
pred_value.to_csv('Fake_news_Prediction.csv')
